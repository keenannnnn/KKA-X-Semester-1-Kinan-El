# %% [markdown]
# <a href="https://colab.research.google.com/github/keenannnnn/KKA-X-Semester-1-Kinan-El/blob/main/Aplikasi_Menghitung_Luas_Persegi_Panjang_Kinan_X.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama = Muhammad Kinan El Khalili
# Kelas = X.1
# Absen = 19

# %% [markdown]
# #Aplikasi Menghitung Luas Persegi Panjang

# %%
panjang = int(input("Masukkkin panjang persegi panjangnya bro (cm): "))
lebar = int(input("Masukkin juga lah lebarnya (cm): "))

luas = panjang * lebar
print(f"Nih luas persegi panjangnya {luas} cm²😹")
# Out:
# Masukkkin panjang persegi panjangnya bro (cm): 5
# Masukkin juga lah lebarnya (cm): 3
# Nih luas persegi panjangnya 15 cm²😹

# %% [markdown]
# #Aplikasi Menghitung Volume Kerucut

# %%
jari_jari = int(input("Masukkan jari jari dari kerucut (cm): "))
tinggi = int(input("Masukkan tinggi dari kerucut (cm): "))
phi = 3.14

volume = (1/3) * phi * jari_jari ** 2 * tinggi

print(f"\nVolume dari kerucutnya adalah {volume} cm³")
# Out:
# Masukkan jari jari dari kerucut (cm): 7
# Masukkan tinggi dari kerucut (cm): 8
#
# Volume dari kerucutnya adalah 410.2933333333333 cm³
